# %%
# %%
from utils import get_reviews, results
from bert_classifier import BertClass
fier
import pandas aimport cufflinks as cf
s pd

# %%
make_bert = lambda: BertClassifier(n_epochs=10, batch_size=32, val_size=0.1)
df = get_reviews()

df_results = (
    pd.DataFrame(results(
        df,
        make_model=make_bert,
        n_data_points=[1000, 10000, 20000, 35000, int(len(df)*0.85)],
        batch_size_inference=None,
        test_size=0.15
    ))
    .set_index('n_data_points')
)
# Out:
# Fits for number of data points:1000
# Epoch 1/10
# 28/28 [==============================] - 13s 464ms/step - loss: 0.6879 - accuracy: 0.5357 - val_loss: 0.6796 - val_accuracy: 0.5854
# Epoch 2/10
# 28/28 [==============================] - 12s 427ms/step - loss: 0.6855 - accuracy: 0.5652 - val_loss: 0.6785 - val_accuracy: 0.5915
# Epoch 3/10
# 28/28 [==============================] - 12s 420ms/step - loss: 0.6804 - accuracy: 0.5502 - val_loss: 0.6701 - val_accuracy: 0.5854
# Epoch 4/10
# 28/28 [==============================] - 12s 420ms/step - loss: 0.6746 - accuracy: 0.5686 - val_loss: 0.6648 - val_accuracy: 0.5854
# Epoch 5/10
# 28/28 [==============================] - 12s 417ms/step - loss: 0.6710 - accuracy: 0.5986 - val_loss: 0.6620 - val_accuracy: 0.6098
# Epoch 6/10
# 28/28 [==============================] - 12s 414ms/step - loss: 0.6692 - accuracy: 0.6874 - val_loss: 0.6630 - val_accuracy: 0.7195
# Epoch 7/10
# ...

# %%
df_results = pd.read_csv('data/bert_results.csv')

ax1 = df_results['n_data_points'].plot(title='Number of data points (left) and test set accuracy (right')
ax2 = ax1.twinx()
df_results['accuracy'].plot(ax=ax2, color='red', figsize=(10,6))

# %%
df_results.iplot(title='Number of data points and test set accuracy')
# Out:
# <div>
#
#
#             <div id="ac47844d-9d32-4bcb-a22f-a607230530a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ac47844d-9d32-4bcb-a22f-a607230530a7")) {
#                     Plotly.newPlot(
#                         'ac47844d-9d32-4bcb-a22f-a607230530a7',
# ...
